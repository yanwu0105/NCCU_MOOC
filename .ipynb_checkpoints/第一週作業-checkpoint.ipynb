# %% [markdown]
# # 第一周作業

# %% [markdown]
# ## 第一題

# %%
# %pylab inline
plot([1,1,2,3,3],[2,7,2,7,2])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 第二題

# %%
plot([19.1,19.6,22.1,25.7,29.2,32,34.3,33.8,31.1,27.5,24.2,20.7],
     [13.9,14.2,15.8,19,22.3,24.6,26.3,26.1,24.8,22.3,19.3,15.6])

# %% [markdown]
# ## 挑戰題一

# %%
a = input("價格1 = ")
b = input("價格2 = ")
c = input("價格3 = ")
d = input("價格4 = ")

b1 = int(a) + int(b) 
c1 = b1 + int(c) 
d1 = c1 + int(d)

plot([a,b1,c1,d1])
# Out:
# 價格1 = 100
# 價格2 = 150
# 價格3 = 230
# 價格4 = 80

# %%
int(a)+int(b)+int(c)+int(d)
# Out:
# 560

# %%
data = [int(a),int(b),int(c),int(d)]
pie(data,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x28d3df54828>,
# ...
#   <matplotlib.text.Text at 0x28d3df75ac8>])
