# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
# %ls
# Out:
#  磁碟區 H 中的磁碟是 新增磁碟區
#  磁碟區序號:  5676-E4B6
#
#  H:\python_yan\MOOC\w5 的目錄
#
# 2017/11/23  下午 05:55    <DIR>          .
# 2017/11/23  下午 05:55    <DIR>          ..
# 2017/11/23  下午 05:41    <DIR>          .ipynb_checkpoints
# 2017/09/19  下午 06:46             2,406 grades.csv
# 2017/11/23  下午 05:55             1,750 w5.ipynb
#                2 個檔案           4,156 位元組
#                3 個目錄  675,212,767,232 位元組可用

# %%
df = pd.read_csv("grades.csv")

# %%
#查看前幾筆
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %%
df["國文"]
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
# 5     13
# 6     11
# 7      8
# 8      9
# 9     10
# 10    14
# 11    13
# 12    11
# 13    15
# 14     8
# 15    11
# 16    14
# 17    12
# 18     9
# 19    14
# 20    13
# 21     9
# 22    12
# 23    10
# 24    10
# 25    13
# 26    13
# 27     8
# 28    15
# 29    14
#       ..
# 70     9
# 71     9
# 72    10
# 73    13
# 74    14
# 75    13
# 76     9
# 77    13
# 78    12
# 79     9
# 80    13
# 81    11
# 82    11
# 83    10
# 84    10
# 85    10
# 86    11
# 87    10
# 88    11
# 89    13
# 90     8
# 91    14
# 92     8
# 93    11
# 94    10
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
# 5     13
# 6     11
# 7      8
# 8      9
# 9     10
# 10    14
# 11    13
# 12    11
# 13    15
# 14     8
# 15    11
# 16    14
# 17    12
# 18     9
# 19    14
# 20    13
# 21     9
# 22    12
# 23    10
# 24    10
# 25    13
# 26    13
# 27     8
# 28    15
# 29    14
#       ..
# 70     9
# 71     9
# 72    10
# 73    13
# 74    14
# 75    13
# 76     9
# 77    13
# 78    12
# 79     9
# 80    13
# 81    11
# 82    11
# 83    10
# 84    10
# 85    10
# 86    11
# 87    10
# 88    11
# 89    13
# 90     8
# 91    14
# 92     8
# 93    11
# 94    10
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %%
cg = df.國文.values

# %%
cg
# Out:
# array([ 9, 10, 13, 10, 13, 13, 11,  8,  9, 10, 14, 13, 11, 15,  8, 11, 14,
#        12,  9, 14, 13,  9, 12, 10, 10, 13, 13,  8, 15, 14,  8, 15,  9, 14,
#        13, 14, 12, 11,  8,  9, 12, 14, 14, 12, 13,  9, 14,  8, 15, 10, 12,
#        14, 12, 14, 15,  9, 11, 12, 10, 11, 14, 14,  8, 12,  9, 13, 10, 14,
#         8, 12,  9,  9, 10, 13, 14, 13,  9, 13, 12,  9, 13, 11, 11, 10, 10,
#        10, 11, 10, 11, 13,  8, 14,  8, 11, 10,  9,  8, 14, 15,  9], dtype=int64)

# %%
cg.mean()
# Out:
# 11.390000000000001

# %%
#標準差
cg.std()
# Out:
# 2.1858407993264284

# %%
df.國文.plot()

# %%
#長條圖 bins區間
df.國文.hist(bins=15)

# %%
# 敘述統計 summary
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %%
#相關係數
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %%
df.國文.corr(df.數學)
# Out:
# -0.31089898221793311

# %%
df["總級分"] = df[["國文","英文","數學","自然","社會"]].sum(1)

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %%
df["主科"] = df.數學*1.5 + df.英文

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分    主科
# 0  劉俊安   9  10  15  10  13   57  32.5
# 1  胡玉華  10  10  10   8   9   47  25.0
# 2  黃淑婷  13  15   8  11  14   61  27.0
# 3  陳上紫  10  10   8   9  14   51  22.0
# 4  崔靜成  13  12  14  12  13   64  33.0

# %%
df.sort_values(by="總級分", ascending=False).head(20)
# ascending=False 由大到小
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分    主科
# 80  施雅鈴  13  15  12  13  13   66  33.0
# 12  李正偉  11  15  11  14  15   66  31.5
# 54  陳怡潔  15  15   9  15  11   65  28.5
# 25  蔡亦瑄  13  13  14  13  12   65  34.0
# 57  胡淳茜  12  15  14  13  11   65  36.0
# 37  曾怡君  11  12  15  13  14   65  34.5
# 48  陳怡婷  15  14  12   9  15   65  32.0
# 64  俞志峰   9  14  13  14  15   65  33.5
# 83  李士賢  10  14  15  13  13   65  36.5
# 87  趙偉希  10  13  14  13  15   65  34.0
# 4   崔靜成  13  12  14  12  13   64  33.0
# 36  詹威德  12  13  15  10  14   64  35.5
# 11  周皇樺  13   9  13  14  15   64  28.5
# 68  劉麗芬   8  14  14  14  14   64  35.0
# 67  林哲法  14   9  15  10  14   62  31.5
# 20  陳智超  13   9  13  14  13   62  28.5
# 24  陳竹伯  10  12  15  10  14   61  34.5
# 65  謝雅琳  13  14  13  12   9   61  33.5
# 76  周育霖   9  12  15  13  12   61  34.5
# 44  童心怡  13  13  14   8  13   61  34.0

# %%
df.sort_values(by=["主科","總級分"], ascending=False).head(20)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分    主科
# 73  吳志遠  13  15  15   8   8   59  37.5
# 83  李士賢  10  14  15  13  13   65  36.5
# 57  胡淳茜  12  15  14  13  11   65  36.0
# 36  詹威德  12  13  15  10  14   64  35.5
# 70  葉儀依   9  13  15   8  14   59  35.5
# 68  劉麗芬   8  14  14  14  14   64  35.0
# 66  邱盈俊  10  14  14  13   8   59  35.0
# 37  曾怡君  11  12  15  13  14   65  34.5
# 24  陳竹伯  10  12  15  10  14   61  34.5
# 76  周育霖   9  12  15  13  12   61  34.5
# 25  蔡亦瑄  13  13  14  13  12   65  34.0
# 87  趙偉希  10  13  14  13  15   65  34.0
# 44  童心怡  13  13  14   8  13   61  34.0
# 27  馮白屏   8  13  14   8  10   53  34.0
# 64  俞志峰   9  14  13  14  15   65  33.5
# 65  謝雅琳  13  14  13  12   9   61  33.5
# 90  胡勝傑   8  11  15  10  15   59  33.5
# 85  張雅彬  10  11  15  12   8   56  33.5
# 80  施雅鈴  13  15  12  13  13   66  33.0
# 4   崔靜成  13  12  14  12  13   64  33.0

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[ 0.3603948 , -0.36399197, -1.02592996],
#        [ 1.13393587,  0.59036674, -0.41861535],
#        [-1.76952071,  1.74029139, -1.86309054],
#        [ 0.58052243,  0.24748419,  1.93349689]])

# %%
list("ABCDE")
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
list("甲乙丙丁")
# Out:
# ['甲', '乙', '丙', '丁']

# %%
df1 = pd.DataFrame(mydata, columns=list("ABC"))

# %%
df1
# Out:
#           A         B         C
# 0  0.360395 -0.363992 -1.025930
# 1  1.133936  0.590367 -0.418615
# 2 -1.769521  1.740291 -1.863091
# 3  0.580522  0.247484  1.933497

# %%
df2 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0  1.579604 -0.290781 -1.568869
# 1 -2.301380  1.580753  1.395336
# 2 -1.060111  1.013905 -0.484944

# %%
df3 = pd.concat([df1, df2], axis=0)

# %%
df3
# Out:
#           A         B         C
# 0  0.360395 -0.363992 -1.025930
# 1  1.133936  0.590367 -0.418615
# 2 -1.769521  1.740291 -1.863091
# 3  0.580522  0.247484  1.933497
# 0  1.579604 -0.290781 -1.568869
# 1 -2.301380  1.580753  1.395336
# 2 -1.060111  1.013905 -0.484944

# %%
df3.index = range(7)

# %%
df3
# Out:
#           A         B         C
# 0  0.360395 -0.363992 -1.025930
# 1  1.133936  0.590367 -0.418615
# 2 -1.769521  1.740291 -1.863091
# 3  0.580522  0.247484  1.933497
# 4  1.579604 -0.290781 -1.568869
# 5 -2.301380  1.580753  1.395336
# 6 -1.060111  1.013905 -0.484944

# %%
df4 = pd.concat([df1,df2],axis=1)

# %%
df4
# Out:
#           A         B         C         A         B         C
# 0  0.360395 -0.363992 -1.025930  1.579604 -0.290781 -1.568869
# 1  1.133936  0.590367 -0.418615 -2.301380  1.580753  1.395336
# 2 -1.769521  1.740291 -1.863091 -1.060111  1.013905 -0.484944
# 3  0.580522  0.247484  1.933497       NaN       NaN       NaN

# %%
df = pd.read_csv("ufo.csv")

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df_state = df.groupby("State").count()

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# KS      176               33             144   176
# KY      244               34             220   244
# LA      172               16             148   174
# MA      322               50             276   322
# MD      215               34             185   215
# ME      181               28             153   181
# MI      590               78             504   591
# MN      254               40             223   254
# MO      448               86             386   448
# MS      139               17             126   139
# MT      143               22             114   144
# NC      356               55             325   356
# ND       51                5              43    51
# NE      101                7              89   101
# NH      124               20             113   125
# NJ      370               51             326   370
# NM      241               28             193   241
# NV      281               45             236   284
# NY      913              123             823   914
# OH      665               93             605   667
# OK      193               22             167   193
# OR      534               89             414   534
# PA      598               97             519   598
# RI       67                8              62    67
# SC      166               22             148   166
# SD       57               10              39    57
# TN      286               41             247   286
# TX     1025              138             923  1027
# UT      193               36             172   193
# VA      299               51             253   299
# VT       44                6              34    44
# WA     1320              269             925  1322
# WI      357               63             312   357
# WV      131               13             112   132
# WY       69                6              57    69

# %%
df_state.sort_values(by="Time", ascending=False, inplace=True)

# %%
df_state.head()
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837

# %%
df_state[:10].Time.plot(kind="bar")

# %%
df = pd.DataFrame(np.random.randn(5,3),
                 index=list(range(1,6)),
                 columns=list("ABC"))

# %%
df
# Out:
#           A         B         C
# 1  1.060316 -0.120344  0.552038
# 2 -1.555863 -0.091917  0.702350
# 3 -0.363152  0.477641  1.116701
# 4  0.381610 -0.960998 -1.883203
# 5  0.003901  0.627813 -0.590591

# %%
df[df.B>0]
# Out:
#           A         B         C
# 3 -0.363152  0.477641  1.116701
# 5  0.003901  0.627813 -0.590591

# %%
df[df.B>0]["C"] = 0
# Out:
# C:\Users\yanwu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#           A         B         C
# 1  1.060316 -0.120344  0.552038
# 2 -1.555863 -0.091917  0.702350
# 3 -0.363152  0.477641  1.116701
# 4  0.381610 -0.960998 -1.883203
# 5  0.003901  0.627813 -0.590591

# %%
df.loc[3, "B"] = 1

# %%
df
# Out:
#           A         B         C
# 1  1.060316 -0.120344  0.552038
# 2 -1.555863 -0.091917  0.702350
# 3 -0.363152  1.000000  1.116701
# 4  0.381610 -0.960998 -1.883203
# 5  0.003901  0.627813 -0.590591

# %%
df.loc[df.B>0, "C"] = 0

# %%
df
# Out:
#           A         B         C
# 1  1.060316 -0.120344  0.552038
# 2 -1.555863 -0.091917  0.702350
# 3 -0.363152  1.000000  0.000000
# 4  0.381610 -0.960998 -1.883203
# 5  0.003901  0.627813  0.000000

# %% [markdown]
# # 安裝 pandas-datareader
#
# conda install pandas-datareader
#
# 更新
#
# conda update pandas-datareader

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader("AAPL", "yahoo", start="2012-9-1", end="2017-8-31")

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-08-31  95.321426  95.514282  93.892860  95.034286  85.557686  84580300
# 2012-09-04  95.108574  96.448570  94.928574  96.424286  86.809074  91973000
# 2012-09-05  96.510002  96.621429  95.657143  95.747147  86.199463  84093800
# 2012-09-06  96.167145  96.898575  95.828575  96.610001  86.976288  97799100
# 2012-09-07  96.864288  97.497147  96.538574  97.205711  87.512573  82416600

# %%
P = df["Adj Close"]

# %%
P.head()
# Out:
# Date
# 2012-08-31    85.557686
# 2012-09-04    86.809074
# 2012-09-05    86.199463
# 2012-09-06    86.976288
# 2012-09-07    87.512573
# Name: Adj Close, dtype: float64

# %%
P.plot()

# %%
P.diff()
#跟前一期比
# Out:
# Date
# 2012-08-31         NaN
# 2012-09-04    1.251388
# 2012-09-05   -0.609611
# 2012-09-06    0.776825
# 2012-09-07    0.536285
# 2012-09-10   -2.276420
# 2012-09-11   -0.276505
# 2012-09-12    1.183220
# 2012-09-13    1.696396
# 2012-09-14    1.067467
# 2012-09-17    1.093208
# 2012-09-18    0.273941
# 2012-09-19    0.024445
# 2012-09-20   -0.437272
# 2012-09-21    0.178719
# 2012-09-24   -1.196075
# 2012-09-25   -2.218552
# 2012-09-26   -1.075180
# 2012-09-27    2.075783
# 2012-09-28   -1.828827
# 2012-10-01   -0.991623
# 2012-10-02    0.246948
# 2012-10-03    1.304131
# 2012-10-04   -0.598053
# 2012-10-05   -1.827584
# 2012-10-08   -1.854568
# 2012-10-09   -0.298409
# 2012-10-10    0.650795
# 2012-10-11   -1.647529
# 2012-10-12    0.207069
#                 ...
# 2017-07-21   -0.069473
# 2017-07-24    1.806381
# 2017-07-25    0.645157
# 2017-07-26    0.714600
# 2017-07-27   -2.878312
# 2017-07-28   -1.052078
# 2017-07-31   -0.764236
# 2017-08-01    1.310135
# 2017-08-02    7.036972
# 2017-08-03   -1.558258
# 2017-08-04    0.813858
# 2017-08-07    2.401901
# 2017-08-08    1.260498
# 2017-08-09    0.972671
# 2017-08-10   -5.091674
# 2017-08-11    2.152252
# 2017-08-14    2.361511
# 2017-08-15    1.743729
# 2017-08-16   -0.647675
# 2017-08-17   -3.078934
# 2017-08-18   -0.358703
# 2017-08-21   -0.288956
# 2017-08-22    2.560791
# 2017-08-23    0.199280
# 2017-08-24   -0.707459
# 2017-08-25    0.587891
# 2017-08-28    1.604233
# 2017-08-29    1.434845
# 2017-08-30    0.438431
# 2017-08-31    0.647659
# Name: Adj Close, Length: 1258, dtype: float64

# %%
r = P.diff()/P

# %%
r[-100:].plot()

# %% [markdown]
# # 移動平均

# %%
P.rolling(window=20).mean()
# Out:
# Date
# 2012-08-31           NaN
# 2012-09-04           NaN
# 2012-09-05           NaN
# 2012-09-06           NaN
# 2012-09-07           NaN
# 2012-09-10           NaN
# 2012-09-11           NaN
# 2012-09-12           NaN
# 2012-09-13           NaN
# 2012-09-14           NaN
# 2012-09-17           NaN
# 2012-09-18           NaN
# 2012-09-19           NaN
# 2012-09-20           NaN
# 2012-09-21           NaN
# 2012-09-24           NaN
# 2012-09-25           NaN
# 2012-09-26           NaN
# 2012-09-27           NaN
# 2012-09-28     87.552710
# 2012-10-01     87.515090
# 2012-10-02     87.427249
# 2012-10-03     87.435095
# 2012-10-04     87.374196
# 2012-10-05     87.195105
# 2012-10-08     87.037106
# 2012-10-09     86.878011
# 2012-10-10     86.692296
# 2012-10-11     86.339384
# 2012-10-12     85.943453
#                  ...
# 2017-07-21    145.318384
# 2017-07-24    145.606711
# 2017-07-25    145.950123
# 2017-07-26    146.432984
# 2017-07-27    146.667716
# 2017-07-28    146.956539
# 2017-07-31    147.190277
# 2017-08-01    147.515328
# 2017-08-02    148.162948
# 2017-08-03    148.800147
# 2017-08-04    149.406081
# 2017-08-07    150.088439
# 2017-08-08    150.810497
# 2017-08-09    151.570768
# 2017-08-10    151.975713
# 2017-08-11    152.425247
# 2017-08-14    152.967051
# 2017-08-15    153.570235
# 2017-08-16    154.094386
# 2017-08-17    154.498338
# 2017-08-18    154.887827
# 2017-08-21    155.172550
# 2017-08-22    155.553055
# 2017-08-23    155.907793
# 2017-08-24    156.371075
# 2017-08-25    156.916354
# 2017-08-28    157.580058
# 2017-08-29    158.249996
# 2017-08-30    158.590008
# 2017-08-31    159.040315
# Name: Adj Close, Length: 1258, dtype: float64

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=60).mean().plot()
