# %%
1+1
# Out:
# 2

# %%
2+3*8
# Out:
# 26

# %%
2**3
# Out:
# 8

# %%
((1+(2+3))**8)*100
# Out:
# 167961600

# %%
# %pylab inline  
# 數學
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])
#畫 (0,-2) (1,10) (2,3) (3,13) (4,5)

# %%
randn(10)
# Out:
# array([ 0.98432199, -0.13437849,  0.60511577,  0.92771035,  0.130289  ,
#         0.99729897, -1.21133907, -0.98078969, -0.27646697, -0.58294526])

# %%
plot(randn(1000))

# %%
plot([-2,1 ,2.7,3.3],[3,-5,6,0])
#畫 (-2,3)(1,-5)(2.7,6)(3.3,0)

# %% [markdown]
# # 用 markdown 筆記

# %% [markdown]
# 自由作筆記

# %% [markdown]
# # 大標題
#
# ##小標題
#
# 內文。

# %% [markdown]
# ## 分項說明
#
# * pyhton
# * jupyter notebook

# %% [markdown]
# ## 連結
# [東吳大學](http://www.csim.scu.edu.tw/)

# %% [markdown]
# ## 插入圖片
#
# ![圖片](yan.jpg)

# %% [markdown]
# ## 打數學符號
#
# 函數 $f(x)=x^3-2x^2+5$ ,積分
#
# 前後加 $
#
# $$\int_a^b f(x) \,dx $$

# %%
## ($$LaTex 數學語法$$) (強調置中)

# %%
a = 3

# %%
a+7
# Out:
# 10

# %%
a =87

# %%
a
# Out:
# 87

# %%
a**2
# Out:
# 7569

# %%
total = 128+65+77

# %%
total
# Out:
# 270

# %%
total*30.5
# Out:
# 8235.0

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
l = [3,9,10,2,-3,5]

# %%
plot(l)

# %%
l = [3,87,-5,9]
g = [1,2,8,10]

# %%
l+g
#不是這樣算
# Out:
# [3, 87, -5, 9, 1, 2, 8, 10]

# %%
3*l
# Out:
# [3, 87, -5, 9, 3, 87, -5, 9, 3, 87, -5, 9]

# %%
print("hello,world!")
# Out:
# hello,world!

# %%
name = "yan"

# %%
name
# Out:
# 'yan'

# %%
"hello, " + name + "!"
# Out:
# 'hello, yan!'

# %%
print("hello, " + name + "!")
# Out:
# hello, yan!

# %% [markdown]
# # input 指令

# %%
a = input("a = ")
#一定是字串
# Out:
# a = 87

# %%
a
# Out:
# '87'

# %% [markdown]
# # 匯率換算

# %%
m = input("美金價格: ")
# Out:
# 美金價格: 120

# %%
m
# Out:
# '120'

# %%
float(m) * 30.5
# Out:
# 3660.0

# %%
m = input("美金價格: ")
twd = float(m) * 30.5
print("台幣 " + str(twd) + "元")
# Out:
# 美金價格: 300
# 台幣 9150.0元

# %% [markdown]
# # pipi機器人

# %%
a = input(">> ")
print("拍拍")
# Out:
# >> 哭哭
# 拍拍
